# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_csv('PPP_data_to_150k.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91018 entries, 0 to 91017
# Data columns (total 14 columns):
# LoanAmount       91018 non-null float64
# City             91017 non-null object
# State            91018 non-null object
# Zip              91017 non-null float64
# NAICSCode        88767 non-null float64
# BusinessType     90949 non-null object
# RaceEthnicity    91018 non-null object
# Gender           91018 non-null object
# Veteran          91018 non-null object
# NonProfit        3016 non-null object
# JobsRetained     82822 non-null float64
# DateApproved     91018 non-null object
# Lender           91018 non-null object
# CD               91018 non-null object
# dtypes: float64(4), object(10)
# memory usage: 9.7+ MB

# %%
#filter out all unanswered ethnicities
df2 = df[~df.RaceEthnicity.str.contains("Unanswered")]
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6771 entries, 0 to 90993
# Data columns (total 14 columns):
# LoanAmount       6771 non-null float64
# City             6771 non-null object
# State            6771 non-null object
# Zip              6771 non-null float64
# NAICSCode        6768 non-null float64
# BusinessType     6771 non-null object
# RaceEthnicity    6771 non-null object
# Gender           6771 non-null object
# Veteran          6771 non-null object
# NonProfit        110 non-null object
# JobsRetained     6461 non-null float64
# DateApproved     6771 non-null object
# Lender           6771 non-null object
# CD               6771 non-null object
# dtypes: float64(4), object(10)
# memory usage: 793.5+ KB

# %%
hispanic_df = df[df['RaceEthnicity']=='Hispanic']
hispanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 997 entries, 39 to 90909
# Data columns (total 14 columns):
# LoanAmount       997 non-null float64
# City             997 non-null object
# State            997 non-null object
# Zip              997 non-null float64
# NAICSCode        997 non-null float64
# BusinessType     997 non-null object
# RaceEthnicity    997 non-null object
# Gender           997 non-null object
# Veteran          997 non-null object
# NonProfit        34 non-null object
# JobsRetained     956 non-null float64
# DateApproved     997 non-null object
# Lender           997 non-null object
# CD               997 non-null object
# dtypes: float64(4), object(10)
# memory usage: 116.8+ KB

# %%
white_df = df[df['RaceEthnicity'] == 'White']

# %%
df['RaceEthnicity'].unique()
# Out:
# array(['White', 'Unanswered', 'Hispanic',
#        'American Indian or Alaska Native', 'Asian',
#        'Black or African American', 'Puerto Rican'], dtype=object)

# %%
sns.pairplot(hispanic_df)
# Out:
# /Users/jenniferoshea/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/jenniferoshea/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
